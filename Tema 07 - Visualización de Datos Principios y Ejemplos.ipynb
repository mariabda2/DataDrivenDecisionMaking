# %% [markdown]
# # <strong><font color='red'>Visualización de Datos: Principios y Ejemplos</font></strong>
#
# "Las buenas visualizaciones permiten ver lo invisible." — Edward Tufte

# %% [markdown]
# **Librerías**
# <br> Antes de comenzar a explorar nuestros datos, es importante importar las bibliotecas que nos permitirán manipularlos y visualizarlos.

# %%
# Importar librerías 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings


sns.set_context("paper")  # Tamaño de fuente más profesional
sns.set_style("whitegrid")  # Fondo blanco con rejilla sutil

# Oculta TODOS los warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##  **Principios de Diseño para Visualización Efectiva**
#
# Una visualización bien diseñada no solo muestra datos, **los transforma en una historia visual clara e impactante**. Estos principios te ayudarán a comunicar con poder y precisión:
#
# ---
#
# ## 🎯 Claridad**
#
# > Elimina el ruido visual y utiliza títulos, etiquetas y escalas claras para facilitar la comprensión.
#
# - Usa fuentes legibles y colores contrastantes.
# - Añade leyendas completas y ejes bien definidos.
# - Evita decoraciones que no aportan valor.
#
# ---
#
# ## 🎨 Consistencia
#
# > Mantén estilos y colores coherentes a lo largo de todas tus visualizaciones.
#
# - Usa una paleta uniforme.
# - Conserva el tipo de gráfico por categoría.
# - Evita cambios bruscos de formato entre gráficos.
#
# ---
#
# ## 🧠 Enfoque
#
# > Dirige la atención hacia los datos relevantes utilizando color, forma o tamaño como herramientas de énfasis.
#
# - Resalta valores clave con colores contrastantes.
# - Agrega anotaciones para insights importantes.
# - Reduce elementos que distraigan.
#
# ---
#
# ## 🧩 Proporcionalidad
#
# > Representa los datos respetando sus proporciones reales. Evita escalas engañosas o truncadas.
#
# - Verifica que áreas, tamaños y longitudes sean correctas.
# - Mantén escalas coherentes entre gráficos relacionados.
# - Evita modificar el eje Y sin justificación.
#
# ---
#
# ## 👁️ Intuición visual
#
# > Usa tipos de gráficos adecuados que faciliten la comprensión rápida.
#
# - Barras para comparar, líneas para tendencias, pastel solo para proporciones simples.
# - Ordena las categorías lógicamente.
# - Usa convenciones visuales familiares.
#
# ---
#
# ## 🔄 Reducción de complejidad
#
# > Descompón información densa en partes comprensibles.
#
# - Agrupa o categoriza elementos similares.
# - Usa capas visuales o dashboards interactivos.
# - Presenta datos de forma progresiva si hay mucho contenido.
#
# ---
#
# ## 📚 Narrativa visual
#
# > Cuenta una historia con tus datos: guía al lector paso a paso.
#
# - Usa títulos que revelen hallazgos.
# - Resalta eventos o anomalías con anotaciones.
# - Organiza las visualizaciones en secuencia lógica.
#
# ---
#
# ## 🧭 Accesibilidad
#
# > Asegura que todos los usuarios puedan interpretar tus gráficos sin barreras.
#
# - Usa colores accesibles (evita rojo/verde conflictivos).
# - Incluye texto alternativo y etiquetas claras.
# - Prioriza formatos responsivos para distintos dispositivos.
#
# ---

# %% [markdown]
# ## Ejemplos

# %% [markdown]
# ### 🔄 Reducción de complejidad

# %% [markdown]
# #### ❌ Gráfico confuso: Demasiadas categorías y etiquetas saturadas

# %%
productos = [f"Producto {chr(65+i)}" for i in range(15)]
ventas = [10 * (i+1) for i in range(15)]

plt.figure(figsize=(8, 4))
plt.bar(productos, ventas, color="tomato")
plt.title("Ventas por producto")
plt.xticks(rotation=45)
plt.ylabel("Miles de USD")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: Agrupación simplificada para facilitar lectura

# %%
import matplotlib.pyplot as plt

categorias = ["Producto A", "Producto B", "Producto C", "Otros"]
ventas = [120, 100, 90, 60]  # 'Otros' agrupa productos menos relevantes

plt.figure(figsize=(6, 4))
plt.bar(categorias, ventas, color="dodgerblue")
plt.title("Ventas por categoría simplificada")
plt.ylabel("Miles de USD")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📚 Narrativa visual

# %% [markdown]
# #### ❌ Gráfico confuso: datos sin historia ni contexto

# %%
plt.figure(figsize=(8, 4))
plt.plot([2020, 2021, 2022, 2023, 2024], [100, 120, 160, 220, 210])
plt.title("Ventas")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: narrativa clara en pasos

# %%
import matplotlib.pyplot as plt

# Evolución de ventas con evento destacado
años = [2020, 2021, 2022, 2023, 2024]
ventas = [100, 120, 160, 220, 210]

plt.figure(figsize=(8, 4))
plt.plot(años, ventas, marker='o', color="steelblue")
plt.title("Crecimiento de ventas tras el lanzamiento del producto X")
plt.ylabel("Miles de USD")
plt.xlabel("Año")
plt.axvline(2021, color="gray", linestyle="--")
plt.text(2021.2, 180, "Lanzamiento de producto X", color="darkred")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🧭 Accesibilidad

# %% [markdown]
# #### ❌ Gráfico confuso: colores confusos y falta de contexto

# %%
plt.figure(figsize=(6, 4))
plt.bar(["A", "P", "R"], [60, 25, 15], color=["red", "green", "blue"])
plt.title("Solicitudes")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: uso de colores accesibles y texto visible
# python

# %%
import matplotlib.pyplot as plt

categorias = ["Aceptado", "Pendiente", "Rechazado"]
resultados = [60, 25, 15]
colores = ["#0066CC", "#999999", "#CC3300"]  # Altos contrastes y colores distintos para daltónicos

plt.figure(figsize=(6, 4))
barras = plt.bar(categorias, resultados, color=colores)

# Añadir etiquetas visibles
for i, valor in enumerate(resultados):
    plt.text(i, valor + 2, f"{valor}%", ha='center', color='black')

plt.title("Estado de solicitudes")
plt.ylabel("Porcentaje")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🎯 Claridad

# %% [markdown]
# #### ❌ Gráfico confuso: Participación de mercado con pastel sobrecargado

# %%
import matplotlib.pyplot as plt

# Datos simulados
empresas = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
participacion = [12, 10, 9, 8, 7, 6, 6, 6, 6, 5, 5, 4]

# Colores chillones
colores = ['red', 'yellow', 'lime', 'cyan', 'magenta', 'orange', 'purple', 'teal', 'blue', 'pink', 'green', 'brown']

# Gráfico circular sin etiquetas adecuadas
plt.figure(figsize=(6, 6))
plt.pie(participacion, colors=colores)
plt.title("Participación de Mercado (2025)")
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: Ventas trimestrales por producto

# %%
import matplotlib.pyplot as plt

# Datos simulados
productos = ["Producto A", "Producto B", "Producto C"]
trimestres = ["Q1", "Q2", "Q3", "Q4"]
ventas = [[2.5, 3.0, 3.8, 4.2],  # Producto A
          [1.8, 2.2, 2.9, 3.1],  # Producto B
          [1.2, 1.5, 1.7, 2.0]]  # Producto C

# Crear gráfico
plt.figure(figsize=(8, 5))
for i, producto in enumerate(productos):
    plt.plot(trimestres, ventas[i], label=producto, marker="o")

plt.title("Ventas Trimestrales por Producto (2025)")
plt.xlabel("Trimestre")
plt.ylabel("Ventas (Millones USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎨 Consistencia

# %% [markdown]
# #### ❌ Gráfico confuso: gráficos inconsistentes y desconectados

# %%
# Datos alternativos y estilos desordenados
meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun"]
ingresos_2024 = [12, 15, 14, 16, 18, 20]
ingresos_2025 = [14, 17, 15, 19, 21, 23]

# Gráfico 1 con un estilo
plt.figure(figsize=(8, 4))
plt.bar(meses, ingresos_2024, color='orange')
plt.title("2024 INCOME", fontsize=10)
plt.xlabel("MONTH")
plt.ylabel("USD")
plt.tight_layout()
plt.show()

# Gráfico 2 con otro estilo completamente diferente
plt.figure(figsize=(6, 3))
plt.plot(meses, ingresos_2025, linestyle='--', marker='s', color='blue')
plt.title("Ingresos 2025", fontsize=16)
plt.xlabel("Mes")
plt.ylabel("Miles de USD")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: gráficos consistentes de ingresos mensuales

# %%
import matplotlib.pyplot as plt

# Datos simulados
meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun"]
ingresos_2024 = [12, 15, 14, 16, 18, 20]
ingresos_2025 = [14, 17, 15, 19, 21, 23]

# Gráfico 1 (2024)
plt.figure(figsize=(10, 4))
plt.plot(meses, ingresos_2024, marker='o', color='teal')
plt.title("Ingresos Mensuales 2024", fontsize=14)
plt.xlabel("Mes", fontsize=12)
plt.ylabel("Ingresos (mil USD)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# Gráfico 2 (2025), con el mismo estilo
plt.figure(figsize=(10, 4))
plt.plot(meses, ingresos_2025, marker='o', color='teal')
plt.title("Ingresos Mensuales 2025", fontsize=14)
plt.xlabel("Mes", fontsize=12)
plt.ylabel("Ingresos (mil USD)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧠 Enfoque

# %% [markdown]
# #### ❌ Gráfico confuso: sin enfoque visual

# %%
import matplotlib.pyplot as plt

meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun"]
ventas = [120, 150, 170, 210, 180, 160]

plt.figure(figsize=(8, 4))
barras = plt.bar(meses, ventas, color="lightgray")

# Resaltar el mes con mayor venta
indice_max = ventas.index(max(ventas))
barras[indice_max].set_color("orange")
plt.figure(figsize=(8, 4))
plt.bar(meses, ventas, color=["red", "green", "blue", "purple", "cyan", "yellow"])
plt.title("Ventas 2025")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: Resaltar el mes con más ventas

# %%
import matplotlib.pyplot as plt

meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun"]
ventas = [120, 150, 170, 210, 180, 160]

plt.figure(figsize=(8, 4))
barras = plt.bar(meses, ventas, color="lightgray")

# Resaltar el mes con mayor venta
indice_max = ventas.index(max(ventas))
barras[indice_max].set_color("orange")

plt.title("Ventas Mensuales - 2025")
plt.xlabel("Mes")
plt.ylabel("Ventas (mil USD)")
plt.text(meses[indice_max], ventas[indice_max]+5, "Mayor venta", ha='center', color="orange")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧩 Proporcionalidad

# %% [markdown]
# #### ❌ Gráfico confuso: violación de la proporcionalidad

# %%
import matplotlib.pyplot as plt

categorias = ["A", "B", "C"]
valores = [100, 200, 400]

plt.figure(figsize=(6, 4))
plt.bar(categorias, [10, 40, 80], color="tomato")  # Datos reducidos sin justificación
plt.title("Distribución distorsionada")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: gráfico de barras con proporciones reales

# %%
import matplotlib.pyplot as plt

categorias = ["A", "B", "C"]
valores = [100, 200, 400]

plt.figure(figsize=(6, 4))
plt.bar(categorias, valores, color="teal")
plt.title("Distribución proporcional")
plt.ylabel("Cantidad")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 👁️ Intuición visual.

# %% [markdown]
# #### ❌ Gráfico confuso: gráfico desordenado

# %%
import matplotlib.pyplot as plt

categorias = ["Móvil", "Escritorio", "Tablet"]
usuarios = [65, 25, 10]

plt.figure(figsize=(6, 4))
plt.pie(usuarios, labels=["M", "E", "T"], startangle=90)
plt.title("U")
plt.show()

# %% [markdown]
# #### ✅ Gráfico claro: gráfico con íconos y diseño familiar

# %%
import matplotlib.pyplot as plt

categorias = ["Móvil", "Escritorio", "Tablet"]
usuarios = [65, 25, 10]

plt.figure(figsize=(6, 4))
colores = ["#4CAF50", "#2196F3", "#FFC107"]
barras = plt.barh(categorias, usuarios, color=colores)
plt.title("Origen de usuarios web")
plt.xlabel("% del total")

# Agregar anotaciones
for i, v in enumerate(usuarios):
    plt.text(v + 1, i, f"{v}%", va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Buenas prácticas
#
# - **Menos es más:** simplifica siempre que puedas.
# - **Color con propósito:** no lo uses solo como decoración.
# - **Anotaciones útiles:** usa etiquetas breves pero informativas.
# - **Contexto:** incluye unidades, escalas, periodos y fuente.
#
# ---
#
# ## Errores comunes a evitar
#
# - Colores innecesarios o confusos.
# - Gráficos 3D innecesarios.
# - Ejes sin etiquetas.
# - Escalas que distorsionan la información.
#
# ---
#
# Una visualización bien diseñada permite explorar, comunicar e influir. No se trata solo de mostrar datos, sino de **contar una historia con ellos**.
